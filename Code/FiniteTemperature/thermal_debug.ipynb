# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft2, ifft2, ifftshift, fftshift, ifft

from classicalfield_orig import FiniteTempGPE as gpe

# %%
g = gpe(npoints = 2**6, numImagSteps = 2000, numRealSteps = 1, dtcoef = 0.0005, boxthickness = 0.4, Nsamples = 1, runAnim = True, animFileName='test', Tfact = 1, dst = False, vortex = True, winMult=1)
# Out:
# Total Imag Time:  0.4371025562286377
# kmax:  4.0212385965949355
# T:  8.085179925372403
# (2, 64, 64)
# (1, 64, 64)

# %%
g_2 = gpe(npoints = 2**6, numImagSteps = 2000, numRealSteps = 50000, dtcoef = 0.0005, boxthickness = 0.4, Nsamples = 1, runAnim = True, animFileName='test', Tfact = 1, dst = False, vortex = True, winMult=2)
# Out:
# Total Imag Time:  1.342808485031128
# kmax:  4.0212385965949355
# T:  8.085179925372403
# (201, 128, 128)
# (1, 128, 128)

# %%
psik_noise = g.genPsiK()
psik_noise2 = g_2.genPsiK()

# %%
back =  np.sqrt(np.divide(2*g.T,(g.ki[0]**2 + g.ki[1]**2),out = np.zeros_like(g.ki[0]), where=np.abs(g.ki[0]**2 + g.ki[1]**2)>1e-6))

# %%
plt.plot(g.xi[0][0], np.abs(ifft2(psik_noise)[0])**2)

# %%
plt.figure() 
plt.imshow(np.abs(ifft2(psik_noise)))
plt.colorbar()

# %%
coef = g.L/(g.dx**2)
print(coef)
plt.imshow(np.abs(g.gs + ifft2(coef*psik_noise))**2)
plt.colorbar()
# Out:
# 81.92

# %%
plt.figure() 
plt.imshow(np.abs(ifft2(psik_noise)))
plt.colorbar()

# %%
plt.plot()
# Out:
# []

# %%
# plt.figure() 
# plt.imshow(np.abs(coef2*psik_noise2))
# plt.colorbar()

# %%
coef2 = g_2.L/(g_2.dx**2)
print(coef2)
plt.imshow(np.abs(g_2.gs + ifft2(coef2*psik_noise2))**2)
plt.colorbar()
# Out:
# 81.92
