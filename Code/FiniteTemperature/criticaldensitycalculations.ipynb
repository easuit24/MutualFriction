# %%
import numpy as np
import matplotlib.pyplot as plt

from classicalfield_orig import FiniteTempGPE as gpe

# %%
g = gpe(npoints = 2**6, numImagSteps = 2000, numRealSteps = 3000, dtcoef = 0.0005, boxthickness = 0.4, Nsamples = 1, runAnim = True, animFileName = 'test.mp4', Tfact = 1/2, dst = False, vortex = True)
# Out:
# Total Imag Time:  1.2767183780670166
# kmax:  4.0212385965949355
# T:  4.042589962686201
# (13, 128, 128)
# (1, 128, 128)

# %%
print(g.dx)
# Out:
# 0.78125

# %%
m = 1
T = g.T
A = 6.07*10**3 
a = g.dx 
U = g.gpeobj.g 

def nc(m, T, A, a, U): 
    return m*T/(np.pi*2)*np.log(A/(m**2*a**2*U*T))

# %%
print(T/(np.pi*2)*np.log(A/((a**2)*U*T)))
# Out:
# 7.109897804572449

# %%
print(nc(m,T,A,a,U)) # therefore, the density is above that of the critical density so we are in the correct regime
# Out:
# 7.109897804572449

# %%
2*g.T/np.pi
# Out:
# 2.573592701820759
