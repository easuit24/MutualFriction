# %%
import numpy as np
import matplotlib.pyplot as plt

from gpevortex import GPETimeEv as gpev

# %%
g_vort = gpev(L = 50, dtcoef = 0.05,  npoints = 2**9, dim = 2, numRealSteps = 216000, dist = 3, antiV = False)  # going back to the original to make sure that still works

# testing to see if reducing the number of points helps
# If not - look into how to create a sparse window outside of the box instead or reducing the time coefficient and going back to no window

# %%
# %matplotlib widget
g_vort.animatepsi2d_show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
g_vort.animatepsi2d_save()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# g = gpev(L = 35, dim = 2, numImagSteps=2000, numRealSteps = 40000, dist = 2, antiV = False) # an attempt to make the vortices circle around each other and the interference
# #thing happen

# %%
# %matplotlib widget
g_vort.animatepsi2d_save()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure() 
plt.imshow(np.abs(g.psi_init), origin = 'lower')
plt.colorbar() 
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
plt.figure() 
plt.plot(g.xi[0][0], np.abs(g.psi_init[512]))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# check normalization
print(np.sum(np.abs(g.psi_init)**2)*g.dx**2)
print(g.Natoms)
print(np.sum(np.abs(g.psi)**2)*g.dx**2)
# Out:
# 511999.9999999998
# 512000
# 512000.0

# %%
plt.figure() 
plt.imshow(np.abs(g.psi), origin = 'lower')
plt.colorbar() 
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
plt.figure() 
plt.plot(g.xi[0][0], np.abs(g.psi_init[512]))
plt.plot(g.xi[0][0], np.abs(g.psi[512]))
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget

g.animatepsi2d_show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure() 
plt.imshow(np.abs(g.dynpsi)) 
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
g2 = gpev(L = 20, dim = 2, numRealSteps = 1000, dist = 2, antiV = False, imp = True, impPsi = g.dynpsi )

# %%
# %matplotlib widget

g2.animatepsi2d_show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 get_ipython().run_line_magic('matplotlib', 'widget')
# ----> 3 g2.animatepsi2d_show()
#
# NameError: name 'g2' is not defined

# %%
plt.figure() 
plt.plot(g2.time_tracking)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
