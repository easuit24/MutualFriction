# %%
import numpy as np
import matplotlib.pyplot as plt

from vortexclean import GPETimeEv as gpe

# %% [markdown]
# This Jupyter notebook aims to find ways to make the vortex simulation run faster. Possible approaches for the speedup:
#
# 1. Decrease the number of points in the window outside of the box trap
#     a) Make the window smaller
#     b) Make the window more sparse
# 2. Decrease the total number of points for the simulation
# 3. Make the steps in the function itself faster

# %% [markdown]
# neighborhoodtesting.ipynb includes the baseline run to determine how long it takes to run the full simulation

# %%
# Run a baseline simulation to get an idea of how long it takes to run: 

g = gpe(L = 50, npoints = 400, dtcoef = 0.05, dim = 2, numImagSteps= 500, numRealSteps = 216000, dist = 3, antiV = False) # decreasing the number of points
# Out:
# Total Imag Time:  37.59269952774048
# No More Minima...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Run a baseline simulation to get an idea of how long it takes to run:
# ----> 3 g = gpe(L = 50, npoints = 400, dtcoef = 0.05, dim = 2, numImagSteps= 500, numRealSteps = 216000, dist = 3, antiV = False)
#
# File c:\Users\TQC User\Desktop\BECs\vortexclean.py:92, in GPETimeEv.__init__(self, L, dtcoef, npoints, dim, numVort, spawnType, tol, Nfactor, numImagSteps, numRealSteps, antiV, dist, runDyn, imp, impPsi)
#      90     print("Total Imag Time: ", time.time() - t)
#      91     if self.runDyn == True:
# ---> 92         self.simulatevortex()
#      93 else:  # start from the wavefunction import
#      94     self.impPsi = impPsi
#
# File c:\Users\TQC User\Desktop\BECs\vortexclean.py:557, in GPETimeEv.simulatevortex(self)
# ...

# %%
# %matplotlib widget
g.animatepsi2d('test')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
