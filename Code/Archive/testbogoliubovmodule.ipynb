# %%
import numpy as np
import matplotlib.pyplot as plt
from bogoliubov import GPEBogoliubov as gpe

# %%
g = gpe(dim = 1)
# Out:
# 0.44532292578090943
# Avg Noise:  1.9845436697584866
# C:\Users\TQC User\AppData\Roaming\Python\Python38\site-packages\matplotlib\cbook\__init__.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
from scipy.stats import norm

# %%
x = np.linspace(0,5, 101)
plt.figure() 
plt.plot(x, norm.pdf(x, 0, 0.5))

plt.vlines(-0.5, 0, 0.8)
plt.vlines(0.5, 0, 0.8)
plt.show()

# %%
print(g.psinoise)
# Out:
# 0.10295982455843003
