# %%
import numpy as np
import matplotlib.pyplot as plt

from vortexclean import GPETimeEv as gpev

# %%
# test the vortex situation to make sure that if the vortices aren't present, the code figures out how to exit 

g_test = gpev(L = 50, dtcoef = 0.05, dim = 2, numImagSteps= 500, numRealSteps = 216000, dist = 3, antiV = False)
# Out:
# Total Imag Time:  61.56934380531311

# %%
g_vv = gpev(L = 50, dtcoef = 0.05, dim = 2, numImagSteps= 500, numRealSteps = 2000, dist = 3, antiV = False)
# Out:
# Total Imag Time:  58.36536693572998

# %%
print(len(g_vv.snapshots))
# Out:
# 9

# %%
plt.figure()
plt.plot(np.abs(g_vv.snapshots[0][len(g_vv.snapshots[0])//2])**2)
# plt.plot(np.abs(g_vv.psi[len(g_vv.psi)//2])**2)
plt.plot(np.abs(g_vv.snapshots[3][len(g_vv.snapshots[0])//2])**2)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
g_vv.animatepsi2d('test_vv')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
