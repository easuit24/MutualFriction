# %%
import numpy as np
import matplotlib.pyplot as plt

from gpevortex_copy import GPETimeEv as gpe

# %%
g = gpe(dim = 2)

# %%
plt.figure() 
plt.imshow(np.abs(g.psi_init)) 
plt.xlabel('X')
plt.ylabel('Y') 
plt.title('Intialized Wavefunction')
plt.figure()

# %%
plt.figure() 
plt.imshow(np.abs(g.psi)) 
plt.title('Wavefunction after imaginary propagation')
plt.xlabel('X')
plt.ylabel('Y')
plt.figure()
