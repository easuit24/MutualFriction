# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft2, ifft2, dstn, idstn, fftshift, ifftshift

from classicalfield_orig import FiniteTempGPE as gpe

# %% [markdown]
# ### Test to see how the classical field runs without vortex

# %%
g = gpe(npoints = 2**6, numImagSteps = 2000, numRealSteps = 3000, dtcoef = 0.0005, boxthickness = 0.4, Nsamples = 1, runAnim = True, animFileName = 'testboxnovortex.mp4', Tfact = 1/2, dst = False)
# Out:
# No vortices to be spawned
# Total Imag Time:  1.3036456108093262
# kmax:  4.0212385965949355
# T:  4.042589962686201
# (13, 128, 128)
# (1, 128, 128)

# %%
plt.figure() 
plt.plot(g.xi[0][0], np.abs(g.snaps[0][len(g.snaps[0])//2])**2)
plt.plot(g.xi[0][0], np.abs(g.snaps[-1][len(g.snaps[-1])//2])**2)

# %%
plt.figure() 
plt.plot(g.ki[0][0], np.abs(fft2(g.snaps[0])[0])**2)
plt.plot(g.ki[0][0], np.abs(fft2(g.snaps[-1])[0])**2)
plt.xscale('log')
plt.yscale('log')

# %% [markdown]
# ### Test simulation for a vortex-vortex pair

# %% [markdown]
# TODO: Maybe increase the temperature here relative to the interaction energy by decreasing the box size if this works in the other simulation

# %%
g_4 = gpe(npoints = 2**6, numImagSteps = 2000, numRealSteps = 3600000, dtcoef = 0.0005, boxthickness = 0.4, Nsamples = 1, runAnim = True, animFileName = 'testboxvortex8.mp4', Tfact = 1/7, dst = False, vortex = True)
# Out:
# Total Imag Time:  1.2994651794433594
# kmax:  4.0212385965949355
# T:  1.155025703624629
# (14401, 128, 128)
# (1, 128, 128)
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# ...
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# more than 2 vortices
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 g_3 = gpe(npoints = 2**6, numImagSteps = 2000, numRealSteps = 3600000, dtcoef = 0.0005, boxthickness = 0.4, Nsamples = 1, runAnim = True, animFileName = 'testboxvortex8.mp4', Tfact = 1/7, dst = False, vortex = True)
#
# File c:\Users\TQC User\Desktop\BECs2\classicalfield_orig.py:74, in FiniteTempGPE.__init__(self, L, npoints, dim, numImagSteps, numRealSteps, T, boxthickness, Nsamples, winMult, dtcoef, vortex, antiV, Tfact, imp, impPsi, runAnim, animFileName, dst)
#      72     self.animatepsi2d(self.animFileName)
#      73 else:
# ---> 74     self.animatepsi2d_vortex(self.animFileName)
#
# File c:\Users\TQC User\Desktop\BECs2\classicalfield_orig.py:507, in FiniteTempGPE.animatepsi2d_vortex(self, filename)
#     503 anim = animation.FuncAnimation(fig, animate, frames = len(self.snaps), blit = True)
#     505 plt.show()
# --> 507 anim.save(path)
#     509 return anim
#
# File ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\animation.py:1103, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1100 for data in zip(*[a.new_saved_frame_seq() for a in all_anim]):
#    1101     for anim, d in zip(all_anim, data):
#    1102         # TODO: See if turning off blit is really necessary
# -> 1103         anim._draw_next_frame(d, blit=False)
#    1104         if progress_callback is not None:
#    1105             progress_callback(frame_number, total_frames)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\animation.py:1138, in Animation._draw_next_frame(self, framedata, blit)
#    1134 def _draw_next_frame(self, framedata, blit):
#    1135     # Breaks down the drawing of the next frame into steps of pre- and
#    1136     # post- draw, as well as the drawing of the frame itself.
#    1137     self._pre_draw(framedata, blit)
# -> 1138     self._draw_frame(framedata)
#    1139     self._post_draw(framedata, blit)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\animation.py:1767, in FuncAnimation._draw_frame(self, framedata)
#    1763     self._save_seq = self._save_seq[-self._save_count:]
#    1765 # Call the func with framedata and args. If blitting is desired,
#    1766 # func needs to return a sequence of any artists that were modified.
# -> 1767 self._drawn_artists = self._func(framedata, *self._args)
#    1769 if self._blit:
#    1771     err = RuntimeError('The animation function must return a sequence '
#    1772                        'of Artist objects.')
#
# File c:\Users\TQC User\Desktop\BECs2\classicalfield_orig.py:498, in FiniteTempGPE.animatepsi2d_vortex.<locals>.animate(i)
#     496 # fix these:
#     497 if self.vortex:
# --> 498     v1.set_offsets([self.xi[0][0][int((self.vortex_positions[i][0]+1)/self.dx+self.winL/4/self.dx)], self.xi[0][0][int((self.vortex_positions[i][1]+1)/self.dx+self.winL/4/self.dx)]])
#     499     v2.set_offsets([self.xi[0][0][int((self.vortex_positions[i][2]+1)/self.dx+self.winL/4/self.dx)], self.xi[0][0][int((self.vortex_positions[i][3]+1)/self.dx+self.winL/4/self.dx)]])
#     500 time_text.set_text('time = %.1d' % self.time_tracking[i])
#
# IndexError: index 11439 is out of bounds for axis 0 with size 11439

# %%
g_5 = gpe(npoints = 2**6, numImagSteps = 2000, numRealSteps = 3600000, dtcoef = 0.0005, boxthickness = 0.4, Nsamples = 1, runAnim = True, animFileName = 'testboxvortex9.mp4', Tfact = 1/7, dst = False, vortex = True)

# %%
print(2500000/250)
# Out:
# 10000.0

# %%
plt.figure() 
plt.plot(g_3.xi[0][0], np.abs(g_3.snaps[0][len(g_3.snaps[0])//2])**2)
plt.plot(g_3.xi[0][0], np.abs(g_3.snaps[-1][len(g_3.snaps[-1])//2])**2)

# %%
plt.figure() 
plt.plot(g_3.ki[0][0], np.abs(fft2(g_3.snaps[0])[0])**2)
plt.plot(g_3.ki[0][0], np.abs(fft2(g_3.snaps[-1])[0])**2)
plt.xscale('log')
plt.yscale('log')

# %%
print(len(g.snaps))
# Out:
# 2001

# %%
dist = np.sqrt(np.abs(g_3.vortex_positions[:,0]-g_3.vortex_positions[:,2])**2 + np.abs(g_3.vortex_positions[:,1]-g_3.vortex_positions[:,3])**2) 
plt.figure() 
plt.plot(np.linspace(0, g_3.numRealSteps*g_3.gpeobj.dt, len(g_3.snaps)), dist)
plt.xlabel('Time')
plt.ylabel('Vortex Distance')
# Out:
# Text(0, 0.5, 'Vortex Distance')

# %%
ang = np.arctan((g_3.vortex_positions[:,1]-g_3.vortex_positions[:,3])/(g_3.vortex_positions[:,0] - g_3.vortex_positions[:,2]))
plt.figure() 
plt.plot(np.linspace(0, g_3.numRealSteps*g_3.gpeobj.dt, len(g_3.snaps)), ang)
plt.xlabel('Time')
plt.ylabel('Vortex Angle (rad)')
# Out:
# C:\Users\TQC User\AppData\Local\Temp\ipykernel_15916\979881638.py:1: RuntimeWarning: divide by zero encountered in divide
#   ang = np.arctan((g_3.vortex_positions[:,1]-g_3.vortex_positions[:,3])/(g_3.vortex_positions[:,0] - g_3.vortex_positions[:,2]))
# Text(0, 0.5, 'Vortex Angle (rad)')

# %%
print("Temperature: ", g_3.T) 
print("Kinetic Energy: ", g_3.gpeobj.kmax**2/2)
print("Potential Energy: ", np.max(g_3.gpeobj.Vbox))
print("Interaction Energy: ", g_3.gpeobj.g*np.max(np.abs(g.gs)**2))
print("Total Time: ", g_3.numRealSteps*g.gpeobj.dt) 
print("Time Step: ", g_3.gpeobj.dt)
print("Number of Atoms: ", g_3.gpeobj.Natoms)
# Out:
# Temperature:  1.6170359850744807
# Kinetic Energy:  8.085179925372403
# Potential Energy:  10.0
# Interaction Energy:  1.1058421849494142
# Total Time:  9.1552734375
# Time Step:  0.00030517578125
# Number of Atoms:  64000

# %%
g_2.animatepsi2d_vortex('testboxvortex_longanim.mp4')

# %% [markdown]
# TODO: Fix the direction that the arrows go... why do they go the wrong way? Also see why there is an out of bounds error for longer runs.. maybe the issue with vorticies close together? Test frame by frame if things are working and how to fix....

# %%
print(np.shape(g.snaps))
# Out:
# (81, 128, 128)

# %%
snap = 80
plt.figure() 
plt.imshow(np.abs(g.snaps[snap])**2, origin = 'lower', extent = [-g.winL/2, g.winL/2, -g.winL/2, g.winL/2], cmap = plt.cm.hot)
plt.scatter(g.xi[0][0][int((g.vortex_positions[snap][0]+1)/g.dx+g.winL/4/g.dx)], g.xi[0][0][int((g.vortex_positions[snap][1]+1)/g.dx+g.winL/4/g.dx)], s = 10, color = 'blue', alpha = 0.3)
plt.scatter(g.xi[0][0][int((g.vortex_positions[snap][2]+1)/g.dx+g.winL/4/g.dx)], g.xi[0][0][int((g.vortex_positions[snap][3]+1)/g.dx+g.winL/4/g.dx)], s = 10, color = 'blue', alpha = 0.3)

# %%
print(np.shape(g.snaps[0]))
# Out:
# (128, 128)

# %%
psi = g.snaps[0][int(g.L/2/g.dx):int(3*g.L/2/g.dx), int(g.L/2/g.dx):int(3*g.L/2/g.dx)]
psi = g.snaps[0]
print(g.vortex_positions[0][1]/g.dx)
plt.figure() 
plt.imshow(np.abs(psi)**2, origin = 'lower', cmap = plt.cm.hot, extent = [-g.winL, g.winL, -g.winL, g.winL])
plt.scatter(g.xi[0][0][int(g.vortex_positions[0][0]/g.dx + g.winL/4/g.dx)], g.xi[0][0][int(g.vortex_positions[0][1]/g.dx + g.winL/4/g.dx)])
# Out:
# 32.5

# %%
print(g.vortex_positions)
# Out:
# [[27.734375 24.609375 24.609375 25.390625]
#  [27.734375 24.609375 24.609375 25.390625]
#  [24.609375 25.390625 27.734375 25.390625]
#  [24.609375 25.390625 27.734375 25.390625]
#  [24.609375 25.390625 28.515625 25.390625]
#  [24.609375 25.390625 28.515625 25.390625]
#  [24.609375 25.390625 28.515625 25.390625]
#  [24.609375 25.390625 28.515625 25.390625]
#  [24.609375 25.390625 28.515625 25.390625]
#  [24.609375 25.390625 28.515625 25.390625]
#  [24.609375 25.390625 28.515625 25.390625]
#  [24.609375 25.390625 28.515625 25.390625]
#  [24.609375 25.390625 28.515625 25.390625]]

# %% [markdown]
# ### Test Simulation for Vortex-AntiVortex pair

# %%
g = gpe(npoints = 2**6, numImagSteps = 2000, numRealSteps = 30000, dtcoef = 0.0005, boxthickness = 0.4, Nsamples = 1, runAnim = True, animFileName = 'testboxantivortex.mp4', Tfact = 1/10, dst = False, vortex = True, antiV = True)
# Out:
# Total Imag Time:  1.3006253242492676
# kmax:  4.0212385965949355
# T:  0.8085179925372403
# (121, 128, 128)
# (1, 128, 128)

# %%
print(g.vortex_positions)
# Out:
# [[25.390625 24.609375 27.734375 24.609375]
#  [25.390625 24.609375 27.734375 24.609375]
#  [25.390625 24.609375 27.734375 24.609375]
#  [27.734375 24.609375 25.390625 25.390625]
#  [27.734375 24.609375 25.390625 25.390625]
#  [27.734375 24.609375 25.390625 25.390625]
#  [27.734375 24.609375 25.390625 25.390625]
#  [27.734375 24.609375 25.390625 25.390625]
#  [27.734375 24.609375 25.390625 25.390625]
#  [27.734375 24.609375 25.390625 25.390625]
#  [27.734375 24.609375 25.390625 25.390625]
#  [27.734375 24.609375 25.390625 25.390625]
#  [27.734375 24.609375 25.390625 25.390625]]
